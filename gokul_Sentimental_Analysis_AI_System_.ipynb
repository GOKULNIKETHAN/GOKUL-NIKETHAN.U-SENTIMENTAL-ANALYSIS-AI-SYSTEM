# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# Read in data, handling inconsistent number of columns
df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# or
# df = pd.read_csv('/content/Reviews.csv', on_bad_lines='skip')
# or
# df = pd.read_csv('/content/Reviews.csv', error_bad_lines=False) # for Pandas < 1.3.0

print(df.shape)
df = df.head(500)
print(df.shape)
# Out:
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 2134: expected 10 fields, saw 11
# Skipping line 6416: expected 10 fields, saw 11
# Skipping line 14596: expected 10 fields, saw 11
# Skipping line 18887: expected 10 fields, saw 13
# Skipping line 20756: expected 10 fields, saw 21
# Skipping line 22797: expected 10 fields, saw 16
# Skipping line 32464: expected 10 fields, saw 16
# Skipping line 40294: expected 10 fields, saw 11
# Skipping line 42139: expected 10 fields, saw 11
# Skipping line 55997: expected 10 fields, saw 11
# Skipping line 60307: expected 10 fields, saw 11
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 68352: expected 10 fields, saw 11
# Skipping line 72248: expected 10 fields, saw 13
# Skipping line 74117: expected 10 fields, saw 18
# Skipping line 76031: expected 10 fields, saw 16
# Skipping line 93179: expected 10 fields, saw 23
# Skipping line 95297: expected 10 fields, saw 11
# Skipping line 103044: expected 10 fields, saw 12
# Skipping line 104967: expected 10 fields, saw 16
# Skipping line 117222: expected 10 fields, saw 18
# Skipping line 121144: expected 10 fields, saw 12
# Skipping line 123116: expected 10 fields, saw 16
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 135961: expected 10 fields, saw 16
# Skipping line 139751: expected 10 fields, saw 13
# Skipping line 143307: expected 10 fields, saw 11
# Skipping line 149533: expected 10 fields, saw 12
# Skipping line 151397: expected 10 fields, saw 16
# Skipping line 155249: expected 10 fields, saw 11
# Skipping line 159433: expected 10 fields, saw 16
# Skipping line 169633: expected 10 fields, saw 16
# Skipping line 173665: expected 10 fields, saw 12
# Skipping line 175637: expected 10 fields, saw 12
# Skipping line 188598: expected 10 fields, saw 16
# Skipping line 196566: expected 10 fields, saw 11
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 202386: expected 10 fields, saw 15
# Skipping line 206611: expected 10 fields, saw 12
# Skipping line 212370: expected 10 fields, saw 16
# Skipping line 222203: expected 10 fields, saw 14
# Skipping line 225962: expected 10 fields, saw 22
# Skipping line 227607: expected 10 fields, saw 12
# Skipping line 233158: expected 10 fields, saw 15
# Skipping line 235236: expected 10 fields, saw 11
# Skipping line 238987: expected 10 fields, saw 16
# Skipping line 243139: expected 10 fields, saw 13
# Skipping line 247006: expected 10 fields, saw 16
# Skipping line 252736: expected 10 fields, saw 16
# Skipping line 258792: expected 10 fields, saw 12
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 273980: expected 10 fields, saw 17
# Skipping line 275827: expected 10 fields, saw 16
# Skipping line 285090: expected 10 fields, saw 15
# Skipping line 287168: expected 10 fields, saw 16
# Skipping line 289105: expected 10 fields, saw 16
# Skipping line 302411: expected 10 fields, saw 11
# Skipping line 306416: expected 10 fields, saw 11
# Skipping line 310533: expected 10 fields, saw 11
# Skipping line 312158: expected 10 fields, saw 11
# Skipping line 314167: expected 10 fields, saw 14
# Skipping line 319887: expected 10 fields, saw 32
# Skipping line 321726: expected 10 fields, saw 12
# Skipping line 327728: expected 10 fields, saw 16
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 333679: expected 10 fields, saw 14
# Skipping line 343416: expected 10 fields, saw 11
# Skipping line 345539: expected 10 fields, saw 17
# Skipping line 353326: expected 10 fields, saw 16
# Skipping line 357282: expected 10 fields, saw 11
# Skipping line 359269: expected 10 fields, saw 11
# Skipping line 363102: expected 10 fields, saw 11
# Skipping line 364727: expected 10 fields, saw 35
# Skipping line 366675: expected 10 fields, saw 14
# Skipping line 372599: expected 10 fields, saw 11
# Skipping line 374737: expected 10 fields, saw 12
# Skipping line 384743: expected 10 fields, saw 13
# Skipping line 386830: expected 10 fields, saw 14
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 396345: expected 10 fields, saw 11
# Skipping line 400517: expected 10 fields, saw 18
# Skipping line 406639: expected 10 fields, saw 16
# Skipping line 428168: expected 10 fields, saw 11
# Skipping line 440252: expected 10 fields, saw 16
# Skipping line 451258: expected 10 fields, saw 12
# Skipping line 453164: expected 10 fields, saw 11
# Skipping line 455234: expected 10 fields, saw 18
# Skipping line 457458: expected 10 fields, saw 20
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 459365: expected 10 fields, saw 15
# Skipping line 463076: expected 10 fields, saw 12
# Skipping line 477502: expected 10 fields, saw 15
# Skipping line 480905: expected 10 fields, saw 11
# Skipping line 494599: expected 10 fields, saw 16
# Skipping line 505930: expected 10 fields, saw 17
# Skipping line 507840: expected 10 fields, saw 18
# Skipping line 510064: expected 10 fields, saw 12
# Skipping line 512069: expected 10 fields, saw 15
# Skipping line 515551: expected 10 fields, saw 12
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 529495: expected 10 fields, saw 18
# Skipping line 531517: expected 10 fields, saw 11
# Skipping line 537296: expected 10 fields, saw 11
# Skipping line 543291: expected 10 fields, saw 11
# Skipping line 547529: expected 10 fields, saw 16
# Skipping line 555377: expected 10 fields, saw 14
# Skipping line 559322: expected 10 fields, saw 16
# Skipping line 571330: expected 10 fields, saw 11
# Skipping line 573346: expected 10 fields, saw 16
# Skipping line 582730: expected 10 fields, saw 11
# Skipping line 588763: expected 10 fields, saw 12
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 592616: expected 10 fields, saw 11
# Skipping line 596566: expected 10 fields, saw 13
# Skipping line 600810: expected 10 fields, saw 12
# Skipping line 605158: expected 10 fields, saw 16
# Skipping line 608972: expected 10 fields, saw 12
# Skipping line 610904: expected 10 fields, saw 16
# Skipping line 621365: expected 10 fields, saw 13
# Skipping line 627535: expected 10 fields, saw 16
# Skipping line 637300: expected 10 fields, saw 12
# Skipping line 647219: expected 10 fields, saw 11
# Skipping line 651276: expected 10 fields, saw 11
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 655512: expected 10 fields, saw 19
# Skipping line 659702: expected 10 fields, saw 16
# Skipping line 676071: expected 10 fields, saw 13
# Skipping line 690451: expected 10 fields, saw 12
# Skipping line 692241: expected 10 fields, saw 12
# Skipping line 696351: expected 10 fields, saw 25
# Skipping line 698327: expected 10 fields, saw 20
# Skipping line 702554: expected 10 fields, saw 12
# Skipping line 708682: expected 10 fields, saw 11
# Skipping line 712720: expected 10 fields, saw 16
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 726797: expected 10 fields, saw 17
# Skipping line 734896: expected 10 fields, saw 16
# Skipping line 737050: expected 10 fields, saw 12
# Skipping line 739227: expected 10 fields, saw 12
# Skipping line 755029: expected 10 fields, saw 18
# Skipping line 757310: expected 10 fields, saw 12
# Skipping line 772908: expected 10 fields, saw 11
# Skipping line 774812: expected 10 fields, saw 13
# Skipping line 778826: expected 10 fields, saw 17
# Skipping line 780810: expected 10 fields, saw 17
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 788959: expected 10 fields, saw 16
# Skipping line 791113: expected 10 fields, saw 16
# Skipping line 792915: expected 10 fields, saw 12
# Skipping line 810838: expected 10 fields, saw 12
# Skipping line 820234: expected 10 fields, saw 11
# Skipping line 822188: expected 10 fields, saw 16
# Skipping line 826205: expected 10 fields, saw 15
# Skipping line 828068: expected 10 fields, saw 13
# Skipping line 831739: expected 10 fields, saw 16
# Skipping line 841819: expected 10 fields, saw 13
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 863389: expected 10 fields, saw 19
# Skipping line 865172: expected 10 fields, saw 14
# Skipping line 873201: expected 10 fields, saw 12
# Skipping line 879382: expected 10 fields, saw 14
# Skipping line 881245: expected 10 fields, saw 12
# Skipping line 895284: expected 10 fields, saw 13
# Skipping line 903235: expected 10 fields, saw 11
# Skipping line 905313: expected 10 fields, saw 16
# Skipping line 913112: expected 10 fields, saw 16
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 919256: expected 10 fields, saw 14
# Skipping line 925771: expected 10 fields, saw 16
# Skipping line 936060: expected 10 fields, saw 12
# Skipping line 957350: expected 10 fields, saw 82
# Skipping line 959269: expected 10 fields, saw 16
# Skipping line 965329: expected 10 fields, saw 21
# Skipping line 967514: expected 10 fields, saw 16
# Skipping line 982346: expected 10 fields, saw 13
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 988474: expected 10 fields, saw 12
# Skipping line 1000039: expected 10 fields, saw 42
# Skipping line 1001740: expected 10 fields, saw 16
# Skipping line 1005964: expected 10 fields, saw 16
# Skipping line 1023966: expected 10 fields, saw 11
# Skipping line 1026053: expected 10 fields, saw 12
# Skipping line 1028197: expected 10 fields, saw 11
# Skipping line 1030397: expected 10 fields, saw 20
# Skipping line 1036047: expected 10 fields, saw 13
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# <ipython-input-19-41bee01e56c1>:11: ParserWarning: Skipping line 1056487: expected 10 fields, saw 16
# Skipping line 1060493: expected 10 fields, saw 16
# Skipping line 1062767: expected 10 fields, saw 11
# Skipping line 1064858: expected 10 fields, saw 13
# Skipping line 1066876: expected 10 fields, saw 13
# Skipping line 1068930: expected 10 fields, saw 14
# Skipping line 1070926: expected 10 fields, saw 12
# Skipping line 1078845: expected 10 fields, saw 16
#
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')
# (1108872, 10)
# (500, 10)
# <ipython-input-19-41bee01e56c1>:11: DtypeWarning: Columns (0,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Reviews.csv', on_bad_lines='warn')

# %%
df.head()
# Out:
#   Id   ProductId          UserId                      ProfileName  \
# 0  1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1  2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2  3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3  4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4  5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#   HelpfulnessNumerator HelpfulnessDenominator Score          Time  \
# 0                    1                    1.0   5.0  1303862400.0
# 1                    0                    0.0   1.0  1346976000.0
# 2                    1                    1.0   4.0  1219017600.0
# 3                    3                    3.0   2.0  1307923200.0
# 4                    0                    0.0   5.0  1350777600.0
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# Quick EDA

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# Step 1. VADER Seniment Scoring
# We will use NLTK's SentimentIntensityAnalyzer to get the neg/neu/pos scores of the text.
#
# This uses a "bag of words" approach:
#
# *   List item
# *   List item
#
#
# Stop words are removed
# each word is scored and combined to a total score.

# %%
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
# Define the variable 'example' with the desired text.
example = "This is an example text."

sia.polarity_scores(example)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
vaders.head()
# Out:
#   Id    neg    neu    pos  compound   ProductId          UserId  \
# 0  1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1  2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2  3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3  4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4  5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName HelpfulnessNumerator  \
# 0                       delmartian                    1
# 1                           dll pa                    0
# 2  Natalia Corres "Natalia Corres"                    1
# 3                             Karl                    3
# 4    Michael D. Bigham "M. Wassir"                    0
#
#   HelpfulnessDenominator Score          Time                Summary  \
# 0                    1.0   5.0  1303862400.0  Good Quality Dog Food
# 1                    0.0   1.0  1346976000.0      Not as Advertised
# 2                    1.0   4.0  1219017600.0  "Delight" says it all
# 3                    3.0   2.0  1307923200.0         Cough Medicine
# 4                    0.0   5.0  1350777600.0            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# Plot VADER results

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# Step 3. Roberta Pretrained Model
# Use a model trained of a large corpus of data.
# Transformer model accounts for the words but also the context related to other words.

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# This is an example text.
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.11934418, 'roberta_neu': 0.81707466, 'roberta_pos': 0.063581206}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %% [markdown]
# Compare Scores between models

# %%
results_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %% [markdown]
# Step 3. Combine and compare

# %%
sns.pairplot(data=results_df,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()

# %% [markdown]
# Step 4: Review Examples:
# Positive 1-Star and Negative 5-Star Reviews
# Lets look at some examples where the model scoring and review score differ the most

# %%
results_df.query('Score == 1') \
    .sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# 'I felt energized within five minutes, but it lasted for about 45 minutes. I paid $3.99 for this drink. I could have just drunk a cup of coffee and saved my money.'

# %%
results_df.query('Score == 1') \
    .sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %%
# nevative sentiment 5-Star view
results_df.query('Score == 5') \
    .sort_values('roberta_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
results_df.query('Score == 5') \
    .sort_values('vader_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %% [markdown]
# Extra: The Transformers Pipeline
# Quick & easy way to run sentiment predictions

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
sent_pipeline('I love sentiment analysis!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997853636741638}]

# %%
sent_pipeline('Make sure to like and subscribe!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9991742968559265}]

# %%
sent_pipeline('booo')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9936267137527466}]

# %% [markdown]
# The End
